# %%
import random

class Markov(object):
    def __init__(self):
        self.model = {}
        self.state = (None, None)

 
    def add(self, word):
        if self.state in self.model:
            self.model[self.state].append(word)
        else:
            self.model[self.state] = [word]
        self.transition(word)

    def reset(self):
        self.state = (None, None)

    def random_next(self):
        list = self.model[self.state]
        choice = random.choice(list)
        self.transition(choice)
        return choice

    def transition(self, next):
        self.state = (self.state[1], next)

def make_word_model(filename):
    infile = open(filename,encoding='utf8')
    model = Markov()
    for line in infile:
        words = line.split()
        for w in words:
            model.add(w)
        #if you want it to learn the end
        model.add('\n')
    infile.close()
    model.add(None)
    model.reset()
    return model

def generate_word_chain(markov, n):
    words = []
    for i in range(n):
        next = markov.random_next()
        if next is None: break
        words.append(next)
    return " ".join(words)

# %%
model = make_word_model("urdu/faiz.txt")

# %%
model.model
# Out:
# {(None, None): ['شرح'],
#  (None, 'شرح'): ['فراق'],
#  ('شرح', 'فراق'): ['مدح'],
#  ('فراق', 'مدح'): ['لب'],
#  ('مدح', 'لب'): ['مشکبو'],
#  ('لب', 'مشکبو'): ['کریں'],
#  ('مشکبو', 'کریں'): ['\n'],
#  ('کریں', '\n'): ['غربت',
#   'یار',
#   'سینے',
#   'کب',
#   'ہمدم',
#   'آشفتہ',
#   'تر',
#   'یاد',
#   'دل',
#   'شام',
#   'قتل',
#   'ہجر',
#   'تمہاری',
#   'یہ'],
#  ('\n', 'غربت'): ['کدے'],
#  ('غربت', 'کدے'): ['میں'],
#  ('کدے', 'میں'): ['کس', 'وہ', 'آتے', 'محو'],
#  ('میں', 'کس'): ['سے', 'وقت'],
#  ('کس', 'سے'): ['تری', 'جام', 'ہے'],
#  ('سے', 'تری'): ['گفتگو', 'دید'],
#  ('تری', 'گفتگو'): ['کریں'],
#  ('گفتگو', 'کریں'): ['\n'],
#  ('\n', 'یار'): ['آشنا'],
#  ('یار', 'آشنا'): ['نہیں'],
#  ('آشنا', 'نہیں'): ['کوئی'],
#  ('نہیں', 'کوئی'): ['ٹکرائیں', '\n', '\n', '\n'],
#  ('کوئی', 'ٹکرائیں'): ['کس'],
#  ('ٹکرائیں', 'کس'): ['سے'],
#  ('سے', 'جام'): ['\n', 'بھرنے'],
#  ('جام', '\n'): ['کس', 'میں', 'تمہارے', 'شاید', 'یا', 'اشک', 'سلام'],
#  ('\n', 'کس'): ['دل',
#   'حرف',
#   'شہر',
#   'پر',
#   'رہ',
#   'طرح',
#   'نے',
#   'دن',
#   'قدر',
#   'کام',
#   'کارن',
#   'طرح',
#   'طرح',
#   'طرح',
#   'گھڑی',
#   'جگہ',
#   'خواب'],
#  ('کس', 'دل'): ['ربا', 'سے'],
#  ('دل', 'ربا'): ['کے'],
#  ('ربا', 'کے'): ['نام'],
#  ('کے', 'نام'): ['پہ',
#   'سے',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'ساقی'],
#  ('نام', 'پہ'): ['خالی', 'آئیں'],
#  ('پہ', 'خالی'): ['سبو'],
#  ('خالی', 'سبو'): ['کریں'],
#  ('سبو', 'کریں'): ['\n'],
#  ('\n', 'سینے'): ['پہ', 'سے'],
#  ('سینے', 'پہ'): ['ہاتھ', 'رکھو'],
#  ('پہ', 'ہاتھ'): ['ہے'],
#  ('ہاتھ', 'ہے'): ['نہ'],
#  ('ہے', 'نہ'): ['نظر',
#   'مے',
#   'شمع',
#   'بجھا',
#   'زاہد',
#   'قاتل',
#   'وہ',
#   'وہ',
#   'جزا',
#   'جفا',
#   'غیروں',
#   'کوئی',
#   'پوچھ',
#   'خانقاہ',
#   'برکھا',
#   'میری'],
#  ('نہ', 'نظر'): ['کو'],
#  ('نظر', 'کو'): ['تلاش', 'بڑے', 'پسند'],
#  ('کو', 'تلاش'): ['بام'],
#  ('تلاش', 'بام'): ['\n'],
#  ('بام', '\n'): ['دل', 'جب', 'نکھر'],
#  ('\n', 'دل'): ['ساتھ',
#   'کو',
#   'میں',
#   'بہت',
#   'سنبھالے',
#   'کا',
#   'نے',
#   'و',
#   'ٹھہرے',
#   'میں',
#   'بھی',
#   'والو',
#   'سر',
#   'شکنی',
#   'سے',
#   'میں',
#   'کی',
#   'والو',
#   'سے',
#   'ہی',
#   'رہین',
#   'مدعی',
#   'ناامید',
#   'میں',
#   'نشیں',
#   'دکھا',
#   'کو',
#   'حزیں',
#   'سے',
#   'کی',
#   'سے',
#   'تو',
#   'میں',
#   'مرا',
#   'سے',
#   'کی'],
#  ('دل', 'ساتھ'): ['دے'],
#  ('ساتھ', 'دے'): ['تو'],
#  ('دے', 'تو'): ['آج'],
#  ('تو', 'آج'): ['غم'],
#  ('آج', 'غم'): ['آرزو'],
#  ('غم', 'آرزو'): ['کریں'],
#  ('آرزو', 'کریں'): ['\n'],
#  ('\n', 'کب'): ['تک',
#   'یاد',
#   'تک',
#   'تک',
#   'تک',
#   'بھیجو',
#   'ٹھہرے',
#   'جان',
#   'مہکے',
#   'صبح',
#   'تک',
#   'حشر',
#   'تمہارے',
#   'نظر',
#   'اشکوں',
#   'لوٹ'],
#  ('کب', 'تک'): ['سنے',
#   '\n',
#   'اسے',
#   'دل',
#   'رہ',
#   'چین',
#   'یاد',
#   'ابھی',
#   '\n',
#   '\n',
#   '\n'],
#  ('تک', 'سنے'): ['گی'],
#  ('سنے', 'گی'): ['رات'],
#  ('گی', 'رات'): ['کہاں'],
#  ('رات', 'کہاں'): ['تک'],
#  ('کہاں', 'تک'): ['سنائیں'],
#  ('تک', 'سنائیں'): ['ہم'],
#  ('سنائیں', 'ہم'): ['\n'],
#  ('ہم', '\n'): ['شکوے',
#   'رات',
#   'سر',
#   'کبھی',
#   'ہم',
#   'فیضؔ',
#   'رنگ',
#   'سب',
#   'کچھ',
#   'کچھ',
#   'اب',
#   'دیکھیں',
#   'اب',
#   'ان',
#   'کچھ',
#   'یہ',
#   'لو',
#   'خیال',
#   'اب',
#   'کوئی',
#   'زنجیر',
#   'آ',
#   'میری',
#   'زندگی',
#   'موت',
#   'زہر',
#   'قید',
#   'طبع',
#   'اس'],
#  ('\n', 'شکوے'): ['گلے'],
#  ('شکوے', 'گلے'): ['سب'],
#  ('گلے', 'سب'): ['آج'],
#  ('سب', 'آج'): ['ترے'],
#  ('آج', 'ترے'): ['روبرو'],
#  ('ترے', 'روبرو'): ['کریں'],
#  ('روبرو', 'کریں'): ['\n'],
#  ('\n', 'ہمدم'): ['حدیث'],
#  ('ہمدم', 'حدیث'): ['کوئے'],
#  ('حدیث', 'کوئے'): ['ملامت'],
#  ('کوئے', 'ملامت'): ['سنائیو'],
#  ('ملامت', 'سنائیو'): ['\n'],
#  ('سنائیو', '\n'): ['دل'],
#  ('دل', 'کو'): ['لہو',
#   'سنبھالو',
#   'مصفا',
#   'قرار',
#   'راہ',
#   'احساس',
#   'گنہ',
#   'سنبھالو',
#   '\n',
#   'پری',
#   'مصفا'],
#  ('کو', 'لہو'): ['کریں'],
#  ('لہو', 'کریں'): ['یا'],
#  ('کریں', 'یا'): ['گریباں'],
#  ('یا', 'گریباں'): ['رفو'],
#  ('گریباں', 'رفو'): ['کریں'],
#  ('رفو', 'کریں'): ['\n'],
#  ('\n', 'آشفتہ'): ['سر'],
#  ('آشفتہ', 'سر'): ['ہیں'],
#  ('سر', 'ہیں'): ['محتسبو'],
#  ('ہیں', 'محتسبو'): ['منہ'],
#  ('محتسبو', 'منہ'): ['نہ'],
#  ('منہ', 'نہ'): ['آئیو'],
#  ('نہ', 'آئیو'): ['\n'],
#  ('آئیو', '\n'): ['سر'],
#  ('\n', 'سر'): ['بیچ',
#   'عام',
#   'خوشی',
#   'کوئے',
#   'کرو',
#   'پر',
#   'وہی',
#   'پھوڑتی',
#   'خسرو',
#   'دیکھنا،',
#   'کوئے',
#   'پٹکنے',
#   'جھکائے',
#   'دریا',
#   'مقتل'],
#  ('سر', 'بیچ'): ['دیں'],
#  ('بیچ', 'دیں'): ['تو'],
#  ('دیں', 'تو'): ['فکر', 'فرشتے'],
#  ('تو', 'فکر'): ['دل'],
#  ('فکر', 'دل'): ['و', 'دارئ', 'تباہ', 'و'],
#  ('دل', 'و'): ['جاں', 'جاں', 'جاں', 'جاں', 'نظر', 'جاں'],
#  ('و', 'جاں'): ['عدو', 'فدائے', 'اپنے', 'سر', 'کا', 'اور', 'میں'],
#  ('جاں', 'عدو'): ['کریں'],
#  ('عدو', 'کریں'): ['\n'],
#  ('\n', 'تر'): ['دامنی'],
#  ('تر', 'دامنی'): ['پہ'],
#  ('دامنی', 'پہ'): ['شیخ'],
#  ('پہ', 'شیخ'): ['ہماری'],
#  ('شیخ', 'ہماری'): ['نہ'],
#  ('ہماری', 'نہ'): ['جائیو'],
#  ('نہ', 'جائیو'): ['\n'],
#  ('جائیو', '\n'): ['دامن'],
#  ('\n', 'دامن'): ['نچوڑ', 'و', 'درد', 'وقت', 'میں', 'میں'],
#  ('دامن', 'نچوڑ'): ['دیں'],
#  ('نچوڑ', 'دیں'): ['تو'],
#  ('تو', 'فرشتے'): ['وضو'],
#  ('فرشتے', 'وضو'): ['کریں'],
#  ('وضو', 'کریں'): ['\n'],
#  ('\n', 'یاد'): ['کا', 'آیا', 'غزال', 'وطن'],
#  ('یاد', 'کا'): ['پھر', 'نقش'],
#  ('کا', 'پھر'): ['کوئی'],
#  ('پھر', 'کوئی'): ['دروازہ'],
#  ('کوئی', 'دروازہ'): ['کھلا'],
#  ('دروازہ', 'کھلا'): ['آخر', 'کوئی'],
#  ('کھلا', 'آخر'): ['شب'],
#  ('آخر', 'شب'): ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n'],
#  ('شب', '\n'): ['دل',
#   'صبح',
#   'وہ',
#   'چاند',
#   'کون',
#   'لمس',
#   'گھر',
#   'جس',
#   'اسی',
#   'آج',
#   'شیشۂ',
#   'وہ',
#   'بے',
#   'نیم'],
#  ('دل', 'میں'): ['بکھری',
#   'کام',
#   'جب',
#   '\n',
#   'آشیانہ',
#   'پھر',
#   'ستارے',
#   'اب',
#   'کیا',
#   'لہو',
#   'یوں',
#   'سجا',
#   'ہے',
#   'وہ',
#   'کبھو',
#   'رہے',
#   'شمشیر',
#   'کوئی',
#   'تمام',
#   'اک',
#   'بجز',
#   'بیتاب',
#   'صداقت'],
#  ('میں', 'بکھری'): ['کوئی', 'شورش'],
#  ('بکھری', 'کوئی'): ['خوشبوئے'],
#  ('کوئی', 'خوشبوئے'): ['قبا'],
#  ('خوشبوئے', 'قبا'): ['آخر'],
#  ('قبا', 'آخر'): ['شب'],
#  ('\n', 'صبح'): ['پھوٹی',
#   'فردا',
#   'کی',
#   'کی',
#   'کی',
#   'گل',
#   'ناشاد',
#   'ہونے',
#   'بغاوت',
#   'پھوٹی',
#   'دم'],
#  ('صبح', 'پھوٹی'): ['تو', 'تو'],
#  ('پھوٹی', 'تو'): ['وہ', 'ہر'],
#  ('تو', 'وہ'): ['پہلو', 'آبروئے', 'ہے'],
#  ('وہ', 'پہلو'): ['سے'],
#  ('پہلو', 'سے'): ['اٹھا'],
#  ('سے', 'اٹھا'): ['آخر'],
#  ('اٹھا', 'آخر'): ['شب'],
#  ('\n', 'وہ'): ['جو',
#   'مرے',
#   'بتوں',
#   'پڑی',
#   'نشاط',
#   'راز',
#   'حیلہ',
#   'چمن',
#   'جب',
#   'تیرگی',
#   'گل',
#   'تو',
#   'مجھ',
#   'بے',
#   'اک',
#   'فرق',
#   'بام',
#   'آئے',
#   'تو',
#   'جو',
#   'دشمن',
#   'رنگ',
#   'شب',
#   'بات',
#   'بات',
#   'رنگ',
#   'دن',
#   'آزمائش',
#   'ساری',
#   'جب',
#   'درد',
#   'مضمحل',
#   'غم',
#   'نظر',
#   'سخن',
#   'خوش',
#   'یار',
#   'جنگ',
#   'عہد',
#   'وقت',
#   'جو',
#   'معصوم',
#   'جو',
#   'جس',
#   'حسن',
#   'آنکھ',
#   'ہونٹ',
#   'حسن',
#   'مضامیں',
#   'خواب',
#   'کہتے',
#   'یہ',
#   'یہ',
#   'کیسی',
#   'کیا',
#   'شورش',
#   'عاشقی',
#   'ایک',
#   'دل',
#   'آنکھ',
#   'جو',
#   'دہکتا',
#   'چیز',
#   'ظلم',
#   'عکس',
#   'پھول',
#   'دل',
#   'پہنچ',
#   'یاد',
#   'شورش',
#   'ساغر',
#   'جس',
#   'جوت',
#   'آگ'],
#  ('وہ', 'جو'): ['اک', 'اب', 'اصحاب', 'خوشبوئے', 'اک'],
#  ('جو', 'اک'): ['عمر', 'تیر', 'اک', 'درد'],
#  ('اک', 'عمر'): ['سے', 'ہونے', 'پڑی', 'ہے'],
#  ('عمر', 'سے'): ['آیا'],
#  ('سے', 'آیا'): ['نہ'],
#  ('آیا', 'نہ'): ['گیا'],
#  ('نہ', 'گیا'): ['آخر'],
#  ('گیا', 'آخر'): ['شب'],
#  ('\n', 'چاند'): ['سے', 'نکلے', 'تارے', 'دیکھا', 'کا', 'نے', 'کے'],
#  ('چاند', 'سے'): ['ماند'],
#  ('سے', 'ماند'): ['ستاروں'],
#  ('ماند', 'ستاروں'): ['نے'],
#  ('ستاروں', 'نے'): ['کہا'],
#  ('نے', 'کہا'): ['آخر'],
#  ('کہا', 'آخر'): ['شب'],
#  ('\n', 'کون'): ['کرتا',
#   'جانے',
#   'قاتل',
#   'کہے',
#   'ہوتا',
#   'ہوتا',
#   'ایسا',
#   'سی',
#   'بے'],
#  ('کون', 'کرتا'): ['ہے'],
#  ('کرتا', 'ہے'): ['وفا', 'اکثر', 'اب'],
#  ('ہے', 'وفا'): ['عہد'],
#  ('وفا', 'عہد'): ['وفا'],
#  ('عہد', 'وفا'): ['آخر', 'کیا', 'یا'],
#  ('وفا', 'آخر'): ['شب'],
#  ('\n', 'لمس'): ['جانانہ'],
#  ('لمس', 'جانانہ'): ['لیے'],
#  ('جانانہ', 'لیے'): ['مستیٔ'],
#  ('لیے', 'مستیٔ'): ['پیمانہ'],
#  ('مستیٔ', 'پیمانہ'): ['لیے'],
#  ('پیمانہ', 'لیے'): ['\n'],
#  ('لیے', '\n'): ['حمد',
#   'روزمرہ',
#   'اور',
#   'اب',
#   'میرا',
#   'پھر',
#   'ہم',
#   'ہر',
#   'کسی',
#   'ہم',
#   'دل',
#   'ساعت',
#   'دین'],
#  ('\n', 'حمد'): ['باری'],
#  ('حمد', 'باری'): ['کو'],
#  ('باری', 'کو'): ['اٹھے'],
#  ('کو', 'اٹھے'): ['دست'],
#  ('اٹھے', 'دست'): ['دعا'],
#  ('دست', 'دعا'): ['آخر', 'گیا'],
#  ('دعا', 'آخر'): ['شب'],
#  ('\n', 'گھر'): ['جو', 'کو', 'رہیے', 'گھر'],
#  ('گھر', 'جو'): ['ویراں'],
#  ('جو', 'ویراں'): ['تھا'],
#  ('ویراں', 'تھا'): ['سر'],
#  ('تھا', 'سر'): ['شام'],
#  ('سر', 'شام'): ['وہ', 'فراق', 'بجھ', 'آتا'],
#  ('شام', 'وہ'): ['کیسے'],
#  ('وہ', 'کیسے'): ['کیسے'],
#  ('کیسے', 'کیسے'): ['\n'],
#  ('کیسے', '\n'): ['فرقت', 'لاکھ'],
#  ('\n', 'فرقت'): ['یار'],
#  ('فرقت', 'یار'): ['نے'],
#  ('یار', 'نے'): ['آباد', 'ارشاد'],
#  ('نے', 'آباد'): ['کیا'],
#  ('آباد', 'کیا'): ['آخر', 'ہے'],
#  ('کیا', 'آخر'): ['شب'],
#  ('\n', 'جس'): ['ادا',
#   'کی',
#   'خاک',
#   'خار',
#   'ادا',
#   'دھج',
#   'دھجی',
#   'نور',
#   'سے',
#   'بار',
#   'سے',
#   'کے',
#   'کی',
#   'کی',
#   'میٹھے',
#   'راہ',
#   'طرح',
#   'میں',
#   'میں',
#   'کو',
#   'طرح',
#   'بیاباں',
#   'سے',
#   'میں',
#   'میں',
#   'سمت',
#   'نے',
#   'کی',
#   'کی',
#   'میں',
#   'کے',
#   'کو',
#   'کی',
#   'طرح',
#   'طرح',
#   'نے',
#   'طرح'],
#  ('جس', 'ادا'): ['سے', 'سے'],
#  ('ادا', 'سے'): ['کوئی', 'یار'],
#  ('سے', 'کوئی'): ['آیا', 'مقتل', 'طرز', '\n'],
#  ('کوئی', 'آیا'): ['تھا'],
#  ('آیا', 'تھا'): ['کبھی', '\n'],
#  ('تھا', 'کبھی'): ['اول'],
#  ('کبھی', 'اول'): ['شب', 'شب'],
#  ('اول', 'شب'): ['\n', '\n'],
#  ('\n', 'اسی'): ['انداز', 'متاع'],
#  ('اسی', 'انداز'): ['سے'],
#  ('انداز', 'سے'): ['چل', 'نبض'],
#  ('سے', 'چل'): ['باد'],
#  ('چل', 'باد'): ['صبا'],
#  ('باد', 'صبا'): ['آخر', 'ہے', 'گیا', 'سے', 'کو'],
#  ('صبا', 'آخر'): ['شب'],
#  ('\n', 'آج'): ['یوں',
#   'ارزاں',
#   'ان',
#   'بکھرائے',
#   'تک',
#   'تم',
#   'کچھ',
#   'کی',
#   'اک',
#   'ہر',
#   'ہر',
#   'بازار',
#   'شب',
#   'شب',
#   'شب',
#   'شب',
#   'کی',
#   'کی',
#   'کی',
#   'کے',
#   'کے',
#   'کا',
#   'مرا',
#   'کی',
#   'تن',
#   'پاؤں',
#   'سے',
#   'کے',
#   'کے',
#   'کا',
#   'کے',
#   'کے',
#   'کے',
#   'شب'],
#  ('آج', 'یوں'): ['موج'],
#  ('یوں', 'موج'): ['در'],
#  ('موج', 'در'): ['موج', 'موج'],
#  ('در', 'موج'): ['غم', 'کسی'],
#  ('موج', 'غم'): ['تھم'],
#  ('غم', 'تھم'): ['گیا'],
#  ('تھم', 'گیا'): ['اس', 'شور', 'شور'],
#  ('گیا', 'اس'): ['طرح'],
#  ('اس', 'طرح'): ['غم', 'اپنی', 'سرمست', 'ہے', 'کہ', 'کہ', 'کہ', 'ہے', 'ہے'],
#  ('طرح', 'غم'): ['زدوں'],
#  ('غم', 'زدوں'): ['کو'],
#  ('زدوں', 'کو'): ['قرار'],
#  ('کو', 'قرار'): ['آ', 'کیسا'],
#  ('قرار', 'آ'): ['گیا'],
#  ('آ', 'گیا'): ['\n', '\n', '\n', '\n', '\n', '\n', 'لاد', '\n', '\n'],
#  ('گیا', '\n'): ['جیسے',
#   'جس',
#   'صبح',
#   'رت',
#   'خون',
#   'سرفروشی',
#   'فیضؔ',
#   'چاند',
#   'وہ',
#   'جو',
#   'نہ',
#   'جو',
#   'ابھی',
#   'یہ',
#   'سنسان',
#   'تھیں',
#   'اب',
#   'کب',
#   'تم'],
#  ('\n', 'جیسے'): ['خوشبوئے', 'ہم', 'بچھڑے', 'چراغ', 'درد'],
#  ('جیسے', 'خوشبوئے'): ['زلف'],
#  ('خوشبوئے', 'زلف'): ['بہار'],
#  ('زلف', 'بہار'): ['آ'],
#  ('بہار', 'آ'): ['گئی', 'گیا'],
#  ('آ', 'گئی'): ['جیسے', 'پھر'],
#  ('گئی', 'جیسے'): ['پیغام'],
#  ('جیسے', 'پیغام'): ['دیدار'],
#  ('پیغام', 'دیدار'): ['یار'],
#  ('دیدار', 'یار'): ['آ'],
#  ('یار', 'آ'): ['گیا'],
#  ('جس', 'کی'): ['دید',
#   'حیرانی',
#   'بیٹی',
#   'پگ',
#   'دید',
#   'تمنا',
#   'رفاقت',
#   'تمنا',
#   'الفت',
#   'ان',
#   'تاریخ'],
#  ('کی', 'دید'): ['و', 'میں'],
#  ('دید', 'و'): ['طلب'],
#  ('و', 'طلب'): ['وہم', 'کے', 'سے'],
#  ('طلب', 'وہم'): ['سمجھے'],
#  ('وہم', 'سمجھے'): ['تھے'],
#  ('سمجھے', 'تھے'): ['ہم'],
#  ('تھے', 'ہم'): ['رو', 'تو', 'جو'],
#  ('ہم', 'رو'): ['بہ'],
#  ('رو', 'بہ'): ['رو'],
#  ('بہ', 'رو'): ['پھر'],
#  ('رو', 'پھر'): ['سر'],
#  ('پھر', 'سر'): ['رہ'],
#  ('سر', 'رہ'): ['گزار', 'گزر', 'گزار', 'سیاہی'],
#  ('رہ', 'گزار'): ['آ', 'چلے'],
#  ('گزار', 'آ'): ['گیا'],
#  ('صبح', 'فردا'): ['کو'],
#  ('فردا', 'کو'): ['پھر'],
#  ('کو', 'پھر'): ['دل', 'سجائے', 'ڈھونڈتا', 'اس'],
#  ('پھر', 'دل'): ['ترسنے', 'وحشی', 'کو'],
#  ('دل', 'ترسنے'): ['لگا'],
#  ('ترسنے', 'لگا'): ['عمر'],
#  ('لگا', 'عمر'): ['رفتہ'],
#  ('عمر', 'رفتہ'): ['ترا', 'پہ'],
#  ('رفتہ', 'ترا'): ['اعتبار'],
#  ('ترا', 'اعتبار'): ['آ'],
#  ('اعتبار', 'آ'): ['گیا'],
#  ('\n', 'رت'): ['بدلنے'],
#  ('رت', 'بدلنے'): ['لگی'],
#  ('بدلنے', 'لگی'): ['رنگ'],
#  ('لگی', 'رنگ'): ['دل'],
#  ('رنگ', 'دل'): ['دیکھنا'],
#  ('دل', 'دیکھنا'): ['رنگ'],
#  ('دیکھنا', 'رنگ'): ['گلشن'],
#  ('رنگ', 'گلشن'): ['سے'],
#  ('گلشن', 'سے'): ['اب'],
#  ('سے', 'اب'): ['حال', 'تک'],
#  ('اب', 'حال'): ['کھلتا'],
#  ('حال', 'کھلتا'): ['نہیں'],
#  ('کھلتا', 'نہیں'): ['\n', 'کچھ'],
#  ('نہیں', '\n'): ['زخم',
#   'ان',
#   'حسن',
#   'تیری',
#   'اپنی',
#   'زیر',
#   'اپنی',
#   'چارۂ',
#   'فیضؔ',
#   'فکر',
#   'معتدل',
#   'صد',
#   'مشکل',
#   'جس',
#   'میدان',
#   'گر',
#   'کسی',
#   'کہ',
#   'وہ',
#   'برس',
#   'نہ',
#   'نگاہ',
#   'یہ',
#   'وہیں',
#   'دل',
#   'جو',
#   'شوق',
#   'دست',
#   'تہمت',
#   'آج',
#   'دکھ',
#   'منتوں',
#   'ان',
#   'وہ',
#   'کسی',
#   'جو',
#   'جسم',
#   'اپنے',
#   'لکھا',
#   'تنگ',
#   'کون',
#   'اس',
#   'شادابیٔ',
#   'جینے',
#   'کیا',
#   'کیا',
#   'ہوں',
#   'چمن',
#   'اسیر'],
#  ('\n', 'زخم'): ['چھلکا', 'سب', 'کتنے'],
#  ('زخم', 'چھلکا'): ['کوئی'],
#  ('چھلکا', 'کوئی'): ['یا'],
#  ('کوئی', 'یا'): ['کوئی'],
#  ('یا', 'کوئی'): ['گل'],
#  ('کوئی', 'گل'): ['کھلا'],
#  ('گل', 'کھلا'): ['اشک'],
#  ('کھلا', 'اشک'): ['امڈے'],
#  ('اشک', 'امڈے'): ['کہ'],
#  ('امڈے', 'کہ'): ['ابر'],
#  ('کہ', 'ابر'): ['بہار'],
#  ('ابر', 'بہار'): ['آ', 'کی', 'کو'],
#  ('\n', 'خون'): ['عشاق', 'دل', 'کے', 'کی', 'کا'],
#  ('خون', 'عشاق'): ['سے'],
#  ('عشاق', 'سے'): ['جام'],
#  ('جام', 'بھرنے'): ['لگے'],
#  ('بھرنے', 'لگے'): ['دل'],
#  ('لگے', 'دل'): ['سلگنے'],
#  ('دل', 'سلگنے'): ['لگے'],
#  ('سلگنے', 'لگے'): ['داغ'],
#  ('لگے', 'داغ'): ['جلنے'],
#  ('داغ', 'جلنے'): ['لگے'],
#  ('جلنے', 'لگے'): ['\n'],
#  ('لگے', '\n'): ['محفل',
#   'اور',
#   'پھر',
#   'عظمت',
#   'اور',
#   'شاید',
#   'اور',
#   'کس',
#   'اور',
#   'کس',
#   'اماں',
#   'اس'],
#  ('\n', 'محفل'): ['درد', 'یار', 'میں', 'ہست'],
#  ('محفل', 'درد'): ['پھر'],
#  ('درد', 'پھر'): ['رنگ'],
#  ('پھر', 'رنگ'): ['پر', 'تکلم', 'پہ'],
#  ('رنگ', 'پر'): ['آ', 'آئے'],
#  ('پر', 'آ'): ['گئی'],
#  ('گئی', 'پھر'): ['شب'],
#  ('پھر', 'شب'): ['آرزو', 'وصل'],
#  ('شب', 'آرزو'): ['پر', 'کا'],
#  ('آرزو', 'پر'): ['نکھار'],
#  ('پر', 'نکھار'): ['آ'],
#  ('نکھار', 'آ'): ['گیا'],
#  ('\n', 'سرفروشی'): ['کے'],
#  ('سرفروشی', 'کے'): ['انداز'],
#  ('کے', 'انداز'): ['بدلے'],
#  ('انداز', 'بدلے'): ['گئے'],
#  ('بدلے', 'گئے'): ['دعوت'],
#  ('گئے', 'دعوت'): ['قتل'],
#  ('دعوت', 'قتل'): ['پر'],
#  ('قتل', 'پر'): ['مقتل'],
#  ('پر', 'مقتل'): ['شہر'],
#  ('مقتل', 'شہر'): ['میں', 'میں'],
#  ('شہر', 'میں'): ['\n',
#   '\n',
#   'فیضؔ',
#   'یاروں',
#   'پھرتا',
#   'چاک',
#   'تیرے',
#   'ہماری'],
#  ('میں', '\n'): ['ڈال',
#   'مرے',
#   'عالم',
#   'یہ',
#   'ورنہ',
#   'خوبیٔ',
#   'پھر',
#   'یہ',
#   'کب',
#   'ابھی',
#   'نماز',
#   'کلہ',
#   'وہاں',
#   'جل',
#   'غلط',
#   'پندار',
#   'چھپ',
#   'کیا',
#   'کسی',
#   'لوہو',
#   'کچھ',
#   'ساری',
#   'ہجوم',
#   'کسی',
#   'ہے',
#   'عشرتیں',
#   'سرخ',
#   'سامنا',
#   'وہ',
#   'رہا',
#   'اس',
#   'جسے',
#   'خزاں',
#   'ہزار',
#   'ہر',
#   'ڈھونڈی',
#   'اس',
#   'اس',
#   'وہم',
#   'جو',
#   'اتنے',
#   'مو',
#   'وہ',
#   'اک',
#   'مہمان',
#   'ہر'],
#  ('\n', 'ڈال'): ['کر'],
#  ('ڈال', 'کر'): ['کوئی'],
#  ('کر', 'کوئی'): ['گردن', 'کاندھے'],
#  ('کوئی', 'گردن'): ['میں'],
#  ('گردن', 'میں'): ['طوق', 'جھولے'],
#  ('میں', 'طوق'): ['آ'],
#  ('طوق', 'آ'): ['گیا'],
#  ('گیا', 'لاد'): ['کر'],
#  ('لاد', 'کر'): ['کوئی'],
#  ('کوئی', 'کاندھے'): ['پہ'],
#  ('کاندھے', 'پہ'): ['دار'],
#  ('پہ', 'دار'): ['آ'],
#  ('دار', 'آ'): ['گیا'],
#  ('\n', 'فیضؔ'): ['کیا',
#   'تکمیل',
#   'جب',
#   'ان',
#   'زندہ',
#   'فرہاد',
#   'تابندگئ',
#   'نہ',
#   'گلشن',
#   'تھی',
#   'ہوتا',
#   'اوج',
#   'تکمیل',
#   'پھر',
#   'سر',
#   'دلوں',
#   'آتے',
#   'اتنے'],
#  ('فیضؔ', 'کیا'): ['جانیے'],
#  ('کیا', 'جانیے'): ['یار', 'کیوں'],
#  ('جانیے', 'یار'): ['کس'],
#  ('یار', 'کس'): ['آس'],
#  ('کس', 'آس'): ['پر'],
#  ('آس', 'پر'): ['منتظر'],
#  ('پر', 'منتظر'): ['ہیں'],
#  ('منتظر', 'ہیں'): ['کہ'],
#  ('ہیں', 'کہ'): ['لائے', 'منزل', 'ہم', 'چشم', 'جس'],
#  ('کہ', 'لائے'): ['گا'],
#  ('لائے', 'گا'): ['کوئی'],
#  ('گا', 'کوئی'): ['خبر'],
#  ('کوئی', 'خبر'): ['\n'],
#  ('خبر', '\n'): ['مے', 'روشن'],
#  ('\n', 'مے'): ['کشوں', 'بہ', 'خانے', 'خانے'],
#  ('مے', 'کشوں'): ['پر'],
#  ('کشوں', 'پر'): ['ہوا'],
#  ('پر', 'ہوا'): ['محتسب', 'جام'],
#  ('ہوا', 'محتسب'): ['مہرباں'],
#  ('محتسب', 'مہرباں'): ['دل'],
#  ('مہرباں', 'دل'): ['فگاروں'],
#  ('دل', 'فگاروں'): ['پہ'],
#  ('فگاروں', 'پہ'): ['قاتل'],
#  ('پہ', 'قاتل'): ['کو'],
#  ('قاتل', 'کو'): ['پیار'],
#  ('کو', 'پیار'): ['آ', 'نہیں'],
#  ('پیار', 'آ'): ['گیا'],
#  ('چاند', 'نکلے'): ['کسی'],
#  ('نکلے', 'کسی'): ['جانب'],
#  ('کسی', 'جانب'): ['تری'],
#  ('جانب', 'تری'): ['زیبائی'],
#  ('تری', 'زیبائی'): ['کا'],
#  ('زیبائی', 'کا'): ['\n'],
#  ('کا', '\n'): ['رنگ',
#   'دولت',
#   'گرمئی',
#   'صحن',
#   'ایک',
#   'دیدہ',
#   'راز',
#   'کس',
#   'آؤ',
#   'دیکھ',
#   'پوچھو',
#   'دیکھو',
#   'اترے',
#   'گو',
#   'تو',
#   'روئے',
#   'وہ',
#   'اوجھل',
#   'محفل',
#   'بہلایا',
#   'کیا',
#   'ہم',
#   'رنگیں',
#   'ہم',
#   'یہ',
#   'کہ',
#   'ہر',
#   'سر',
#   'تنہا',
#   'اک',
#   'وہ'],
#  ('\n', 'رنگ'): ['بدلے', 'پیراہن', 'و'],
#  ('رنگ', 'بدلے'): ['کسی'],
#  ('بدلے', 'کسی'): ['صورت'],
#  ('کسی', 'صورت'): ['شب'],
#  ('صورت', 'شب'): ['تنہائی'],
#  ('شب', 'تنہائی'): ['کا'],
#  ('تنہائی', 'کا'): ['\n', 'زہر', 'کیا', '\n'],
#  ('\n', 'دولت'): ['لب', 'دل'],
#  ('دولت', 'لب'): ['سے'],
#  ('لب', 'سے'): ['پھر', 'ہے', 'ہو', 'تہہ'],
#  ('سے', 'پھر'): ['اے', 'چن', 'ہوگی'],
#  ('پھر', 'اے'): ['خسرو'],
#  ('اے', 'خسرو'): ['شیریں'],
#  ('خسرو', 'شیریں'): ['دہناں'],
#  ('شیریں', 'دہناں'): ['\n', '\n'],
#  ('دہناں', '\n'): ['آج', 'جنوں'],
#  ('آج', 'ارزاں'): ['ہو'],
#  ('ارزاں', 'ہو'): ['کوئی'],
#  ('ہو', 'کوئی'): ['حرف', 'روشن'],
#  ('کوئی', 'حرف'): ['شناسائی'],
#  ('حرف', 'شناسائی'): ['کا'],
#  ('شناسائی', 'کا'): ['\n'],
#  ('\n', 'گرمئی'): ['رشک'],
#  ('گرمئی', 'رشک'): ['سے'],
#  ('رشک', 'سے'): ['ہر'],
#  ('سے', 'ہر'): ['انجمن', 'ایک', 'روز', 'بار', 'اک', 'دم', 'صبح'],
#  ('ہر', 'انجمن'): ['گل'],
#  ('انجمن', 'گل'): ['بدناں'],
#  ('گل', 'بدناں'): ['\n'],
#  ('بدناں', '\n'): ['تذکرہ'],
#  ('\n', 'تذکرہ'): ['چھیڑے'],
#  ('تذکرہ', 'چھیڑے'): ['تری'],
#  ('چھیڑے', 'تری'): ['پیرہن'],
#  ('تری', 'پیرہن'): ['آرائی'],
#  ('پیرہن', 'آرائی'): ['کا'],
#  ('آرائی', 'کا'): ['\n'],
#  ('\n', 'صحن'): ['گلشن', 'گلشن', 'زنداں'],
#  ('صحن', 'گلشن'): ['میں', 'میں'],
#  ('گلشن', 'میں'): ['کبھی', 'بہر', 'صبا', 'کہرام', 'وہی', 'چاک', '\n'],
#  ('میں', 'کبھی'): ['اے', 'کاکل', '\n'],
#  ('کبھی', 'اے'): ['شہ'],
#  ('اے', 'شہ'): ['شمشاد'],
#  ('شہ', 'شمشاد'): ['قداں'],
#  ('شمشاد', 'قداں'): ['\n', 'ہے'],
#  ('قداں', '\n'): ['پھر'],
#  ('\n', 'پھر'): ['نظر',
#   'آج',
#   'لہو',
#   'صبا',
#   'نظر',
#   'تصور',
#   'در',
#   'آج',
#   'آئینۂ',
#   'اپنی',
#   'حریف',
#   'لوٹا',
#   'نور',
#   'آگ',
#   'شعلے',
#   'نکلا',
#   'وہی',
#   'وہی',
#   'وہ',
#   'وہ',
#   'وہی',
#   'وہ',
#   'دم',
#   'شب',
#   'وہاں',
#   'یہاں',
#   'ہمیں',
#   'سے',
#   'کیا',
#   'پئے',
#   'پھریرے',
#   'کف',
#   'نکل',
#   'دہل',
#   'ہم',
#   'دیکھے',
#   'بنیں',
#   'برق',
#   'رنگ',
#   'برق',
#   'دل',
#   'پھولوں',
#   'جھرنے',
#   'دنیا'],
#  ('پھر', 'نظر'): ['آئے', 'میں', 'میں'],
#  ('نظر', 'آئے'): ['سلیقہ'],
#  ('آئے', 'سلیقہ'): ['تری'],
#  ('سلیقہ', 'تری'): ['رعنائی'],
#  ('تری', 'رعنائی'): ['کا'],
#  ('رعنائی', 'کا'): ['\n'],
#  ('\n', 'ایک'): ['بار', 'امید', 'اک', 'بھی', 'پل', 'پل', 'بن', 'افسردہ'],
#  ('ایک', 'بار'): ['اور', 'یہ', 'روانہ', 'ہوتا!'],
#  ('بار', 'اور'): ['مسیحائے'],
#  ('اور', 'مسیحائے'): ['دل'],
#  ('مسیحائے', 'دل'): ['دل'],
#  ('دل', 'دل'): ['زدگاں', 'زدگاں'],
#  ('دل', 'زدگاں'): ['\n', '\n'],
#  ('زدگاں', '\n'): ['کوئی', 'کلمۂ'],
#  ('\n', 'کوئی'): ['وعدہ',
#   'خوشبو',
#   'تصویر',
#   'قصہ',
#   'لمحہ',
#   'پکارو',
#   'یار',
#   'مسیحا',
#   'نغمہ،',
#   'امید،',
#   'غم،',
#   'نہیں',
#   'کرتا',
#   'اترا',
#   'صف',
#   'نہ',
#   'دریدہ',
#   'رگ',
#   'جبیں',
#   'نجات',
#   'دل',
#   'اجڑا',
#   'بت'],
#  ('کوئی', 'وعدہ'): ['کوئی'],
#  ('وعدہ', 'کوئی'): ['اقرار'],
#  ('کوئی', 'اقرار'): ['مسیحائی'],
#  ('اقرار', 'مسیحائی'): ['کا'],
#  ('مسیحائی', 'کا'): ['\n'],
#  ('\n', 'دیدہ'): ['و'],
#  ('دیدہ', 'و'): ['دل', 'دل'],
#  ('و', 'دل'): ['کو', 'کی', 'کی', 'کو', '\n', 'لے', 'کی'],
#  ('کو', 'سنبھالو'): ['کہ', 'جس'],
#  ('سنبھالو', 'کہ'): ['سر'],
#  ('کہ', 'سر'): ['شام', 'موجۂ'],
#  ('شام', 'فراق'): ['\n', 'یاراں'],
#  ('فراق', '\n'): ['ساز', 'مگر'],
#  ('\n', 'ساز'): ['و', 'خوابیدہ', 'سب', 'دل'],
#  ('ساز', 'و'): ['سامان'],
#  ('و', 'سامان'): ['بہم'],
#  ('سامان', 'بہم'): ['پہنچا'],
#  ('بہم', 'پہنچا'): ['ہے'],
#  ('پہنچا', 'ہے'): ['رسوائی', '\n'],
#  ('ہے', 'رسوائی'): ['کا'],
#  ('رسوائی', 'کا'): ['\n'],
#  ('\n', 'راز'): ['الفت'],
#  ('راز', 'الفت'): ['چھپا'],
#  ('الفت', 'چھپا'): ['کے'],
#  ('چھپا', 'کے'): ['دیکھ'],
#  ('کے', 'دیکھ'): ['لیا', 'لیا', 'لیا', 'لیا', 'لیا', 'لیا', 'ہمدم'],
#  ('دیکھ', 'لیا'): ['\n', '\n', '\n', '\n', '\n', '\n'],
#  ('لیا', '\n'): ['دل', 'اور', 'وہ', 'آج', 'فیضؔ', 'ستم', 'ہاتھ', 'آ', 'آ'],
#  ('دل', 'بہت'): ['کچھ'],
#  ('بہت', 'کچھ'): ['جلا'],
#  ('کچھ', 'جلا'): ['کے'],
#  ('جلا', 'کے'): ['دیکھ'],
#  ('\n', 'اور'): ['کیا',
#   'کچھ',
#   'مکیں',
#   'نہیں',
#   'کل',
#   'حد',
#   'اپنی',
#   'اہل',
#   'دل',
#   'یہ',
#   'اپنے',
#   'پھر',
#   'اس',
#   '\n',
#   'صبح',
#   'سایۂ',
#   'اب',
#   'رخشاں',
#   'تاباں',
#   'مری',
#   'نیا',
#   'اس',
#   'ان',
#   'کوئی',
#   'مل',
#   'سارے',
#   'جس',
#   'سارے',
#   'ناؤ',
#   'یاد',
#   'سب',
#   'ٹوٹکے',
#   'بھی',
#   'راہی',
#   'کہیں',
#   'خاموش',
#   'قزاق',
#   'کچھ',
#   'آئے',
#   'کچھ',
#   'آفاق',
#   'اب',
#   'یاد',
#   'اب',
#   'کچھ',
#   'مشرق',
#   'ترتیب',
#   'چاہنے'],
#  ('اور', 'کیا'): ['دیکھنے', 'تو'],
#  ('کیا', 'دیکھنے'): ['کو'],
#  ('دیکھنے', 'کو'): ['باقی'],
#  ('کو', 'باقی'): ['ہے'],
#  ('باقی', 'ہے'): ['\n', 'کون', 'دلدارئ', '\n', '\n', 'جب'],
#  ('ہے', '\n'): ['آپ',
#   'مگر',
#   'کس',
#   'وہ',
#   'میرے',
#   'جو',
#   'تو',
#   'یہ',
#   'سب',
#   'چمن',
#   'دل',
#   'آؤ',
#   'جو',
#   'آج',
#   'ہے',
#   'ہے',
#   'وصل',
#   'بکھری',
#   'دست',
#   'آتے',
#   'ہم',
#   'آئے',
#   'دل',
#   'اب',
#   'اب',
#   'اشک',
#   'یا',
#   'لاکھ',
#   'جاؤ',
#   'بے',
#   'شعر',
#   'نہ',
#   'کسی',
#   'ہوا',
#   'اگر',
#   'کہاں',
#   'ترے',
#   'تلاش',
#   'جنوں',
#   'اگرچہ',
#   'ہوئی',
#   'وہ',
#   'نہ',
#   'عجیب',
#   'چمن',
#   'تیری',
#   'آشنا',
#   'حسن',
#   'صبح',
#   'شیخ',
#   'ذکر',
#   'اشک',
#   'کیسے',
#   'فیضؔ',
#   'چشم',
#   'سر',
#   'کب',
#   'ملتا',
#   'ہر',
#   'احسان',
#   'دربار',
#   'آوارہ',
#   'جس',
#   'جس',
#   'حلقہ',
#   'رہ',
#   'جو',
#   'مقام',
#   'زباں',
#   'ہر',
#   'ہم',
#   'زہر',
#   'تیرے',
#   'بس',
#   'جو',
#   'شاخ',
#   'دل',
#   'فلک',
#   'اب',
#   'وہ',
#   'سیکھی',
#   'ماضی',
#   'کیا',
#   'کچھ',
#   'ہم',
#   'یوں',
#   'بیداد',
#   'ہاں',
#   'اب',
#   'ہم',
#   'کیے',
#   'کلاہ',
#   'جہاں',
#   'وہ',
#   'نہ',
#   'صف',
#   'نہ',
#   'کف',
#   'نہیں',
#   'نہیں',
#   'دشنام',
#   'کرتے',
#   'دل',
#   'اے',
#   'دل',
#   'لمبی',
#   'دست',
#   'آخر',
#   'بھیگی',
#   'ہم',
#   'کیا',
#   'نہ',
#   'احوال',
#   'خوش',
#   'یوں',
#   'اک',
#   'اک',
#   'کیوں',
#   'یوں',
#   'ہر',
#   'ہوس',
#   'شوق',
#   'اب',
#   'آج',
#   'شہر',
#   'دست',
#   'رخت',
#   'آنکھ',
#   'کوئی',
#   'آج',
#   'تم',
#   'آج',
#   'آج',
#   'جب',
#   'جو',
#   'ادھر',
#   'مہتاب',
#   'لیکن',
#   'ہمت',
#   'جب',
#   'اور',
#   'ہم',
#   'درد',
#   'کلرکوں',
#   'دوسری',
#   'جس',
#   'ان',
#   'سیہ',
#   'شب',
#   'کہر',
#   'اے',
#   'یوں',
#   'اے',
#   'پھر',
#   'ہم',
#   'نیاز',
#   'اب',
#   'اب',
#   'گھر',
#   'پیوند',
#   'یاں',
#   'اب',
#   'ہم',
#   'بام',
#   'ہر',
#   'یہ',
#   'یہ',
#   'بیروت',
#   'موج',
#   'اب',
#   'ہم',
#   'یہ',
#   'وہ',
#   'جھنجھنا',
#   'مسکرا',
#   'دن',
#   'جب',
#   'مرنے',
#   'اکیلے',
#   'جس',
#   'اب',
#   'جو',
#   'گر',
#   'گر',
#   'تم',
#   'اب',
#   'جب',
#   'یہ',
#   'تم',
#   'ادائے',
#   'اداس',
#   'وہ',
#   'گر',
#   'صلیب',
#   'طرب',
#   'تنک',
#   'تمیز',
#   'ہے',
#   'وہ',
#   'میں',
#   'وہ',
#   'چراغ',
#   'مگر',
#   'ہر',
#   'حذر',
#   'حذر',
#   'جسے',
#   'جو',
#   'اجل',
#   'کئی',
#   'سکوت',
#   'صبا',
#   'مجھے',
#   'وہ',
#   'آج',
#   'یوں',
#   'ہاں',
#   'امڈی',
#   'وہ',
#   'ہاں',
#   'اس',
#   'مقصود',
#   'احساس',
#   'اس',
#   'ہر',
#   'ہر',
#   'ہر',
#   'تعزیر',
#   'وہ',
#   'زندان',
#   'مجبوری',
#   'طوفاں',
#   'شب',
#   'ہمیں',
#   'ہر',
#   'ہر',
#   'تنہائی',
#   'کیا',
#   'کارواں',
#   'تجھ',
#   'تجھ',
#   'تو',
#   'جز',
#   'آگ',
#   'رات',
#   'جاگ',
#   'عکس',
#   'ہم',
#   'کون',
#   'دیکھو',
#   'بیری',
#   'یہی',
#   'سحر',
#   'اب',
#   'گلزار',
#   'پندار',
#   'پھر',
#   'تائید',
#   'اب',
#   'حسن',
#   'اے',
#   'اے',
#   'زندگی',
#   'پھول',
#   'آسماں',
#   'آ',
#   'پیکر',
#   'آبشار',
#   'چار',
#   'زندگی',
#   'دل',
#   'میرے',
#   'جا',
#   'دور',
#   'تیرا',
#   'کوئی',
#   'آسماں',
#   'جس',
#   'شوپیں',
#   'اک',
#   'جو',
#   'خوں',
#   'شوپیںؔ',
#   'کچھ',
#   'شوپیںؔ',
#   'اک',
#   'شوپیںؔ',
#   'غم',
#   'اک',
#   'شوپیںؔ',
#   'پھر',
#   'شوپیں',
#   'پہلی',
#   'دوسری',
#   'اس',
#   'جو',
#   'اک',
#   'اس',
#   'سب',
#   'نت'],
#  ('\n', 'آپ'): ['سے', 'کی', 'اہل'],
#  ('آپ', 'سے'): ['دل'],
#  ('سے', 'دل'): ['لگا', 'بہلتا', 'و', 'ناصبور', 'لگا', 'اس'],
#  ('دل', 'لگا'): ['کے', 'کے'],
#  ('لگا', 'کے'): ['دیکھ', 'ہستی'],
#  ('وہ', 'مرے'): ['ہو'],
#  ('مرے', 'ہو'): ['کے'],
#  ('ہو', 'کے'): ['بھی', 'تیرے', '\n', 'رہ', 'رہ', 'ابھی'],
#  ('کے', 'بھی'): ['مرے', 'دل'],
#  ('بھی', 'مرے'): ['نہ'],
#  ('مرے', 'نہ'): ['ہوئے'],
#  ('نہ', 'ہوئے'): ['\n'],
#  ('ہوئے', '\n'): ['ان',
#   'وہ',
#   'جو',
#   'پہلے',
#   'پہلے',
#   'اک',
#   'فیضؔ',
#   'اب',
#   'تجھ',
#   'اور',
#   'اور',
#   'اور',
#   'اب',
#   'اب',
#   'سب',
#   'گزر',
#   'سجے',
#   'ان',
#   'جو',
#   'سرد',
#   'جس'],
#  ('\n', 'ان'): ['کو',
#   'دنوں',
#   'کی',
#   'کا',
#   'میں',
#   'دکھی',
#   'حسیناؤں',
#   'بیاہتاؤں',
#   'اسیروں',
#   'آنکھوں',
#   'ہونٹوں',
#   'ہاتھوں',
#   'جسموں',
#   'چہروں',
#   'رشتوں',
#   'صدیوں',
#   'میں',
#   'روشنیوں',
#   'کی',
#   'کو',
#   'سے',
#   'کہی',
#   'کو',
#   'طوق',
#   'شوخ',
#   'سپنوں',
#   'دونوں'],
#  ('ان', 'کو'): ['اپنا', 'ہے', 'سنانے', 'بہت', 'یہ', 'کیا', 'شعلوں', 'تشویش'],
#  ('کو', 'اپنا'): ['بنا'],
#  ('اپنا', 'بنا'): ['کے'],
#  ('بنا', 'کے'): ['دیکھ'],
#  ('آج', 'ان'): ['کی'],
#  ('ان', 'کی'): ['نظر', 'دسترس', 'نظر', 'خو', 'مختصر', 'ادا', 'ٹوہ', 'مانوں'],
#  ('کی', 'نظر'): ['میں', 'میں', '\n', 'میں'],
#  ('نظر', 'میں'): ['کچھ', 'عالم', 'پھول', 'کیا', 'آئے', 'ہے', 'ہے', 'آئے'],
#  ('میں', 'کچھ'): ['ہم', 'واعظ', 'چراغ', 'تو', 'تو', 'میل'],
#  ('کچھ', 'ہم'): ['نے'],
#  ('ہم', 'نے'): ['\n',
#   '\n',
#   'رقص',
#   'خوں',
#   '\n',
#   'بھلا',
#   'قدم',
#   'عاشقانہ',
#   'رقم',
#   'جو',
#   'آتشیں',
#   'توبہ',
#   '\n',
#   'عاشقی',
#   'دل',
#   'فکر',
#   'چمن',
#   'سب',
#   'امید',
#   '\n',
#   '\n',
#   'اب',
#   'دل',
#   '\n',
#   '\n',
#   '\n',
#   'اس',
#   'ان',
#   'نہ'],
#  ('نے', '\n'): ['سب',
#   'سو',
#   'آنکھوں',
#   'کسی',
#   'آسماں',
#   'بحر',
#   'ہر',
#   'تھے',
#   'مے',
#   'یہ',
#   'ہم',
#   'اپنے',
#   'حسرت',
#   'جیون',
#   'اس',
#   'تمہارے',
#   'تم',
#   'جلوۂ',
#   'سارے',
#   'اب',
#   'ہر',
#   'وہ',
#   'ہنس',
#   'دہر',
#   'تجھ',
#   'ہم',
#   'ڈھیر',
#   'پھر',
#   'وہ'],
#  ('\n', 'سب'): ['کی',
#   'پوچھیں',
#   'کچھ',
#   'قتل',
#   'ان',
#   'دیکھنے',
#   'چلے',
#   'بھول',
#   'سے',
#   'دامن',
#   'ساغر'],
#  ('سب', 'کی'): ['نظریں', 'زباں'],
#  ('کی', 'نظریں'): ['بچا'],
#  ('نظریں', 'بچا'): ['کے'],
#  ('بچا', 'کے'): ['دیکھ'],
#  ('فیضؔ', 'تکمیل'): ['غم', 'آرزو'],
#  ('تکمیل', 'غم'): ['بھی'],
#  ('غم', 'بھی'): ['ہو'],
#  ('بھی', 'ہو'): ['نہ', 'آئینۂ', 'منظور'],
#  ('ہو', 'نہ'): ['سکی', 'شب', 'ہو', 'ہو', 'جائے'],
#  ('نہ', 'سکی'): ['\n'],
#  ('سکی', '\n'): ['عشق'],
#  ('\n', 'عشق'): ['کو', 'منت', 'منت', 'میں', 'کے', 'کی', 'دل'],
#  ('عشق', 'کو'): ['آزما', 'دار', 'اک'],
#  ('کو', 'آزما'): ['کے'],
#  ('آزما', 'کے'): ['دیکھ'],
#  ('\n', 'ستم'): ['سکھلائے', 'پہ', 'کی', 'کی'],
#  ('ستم', 'سکھلائے'): ['گا'],
#  ('سکھلائے', 'گا'): ['رسم'],
#  ('گا', 'رسم'): ['وفا'],
#  ('رسم', 'وفا'): ['ایسے', 'کی'],
#  ('وفا', 'ایسے'): ['نہیں'],
#  ('ایسے', 'نہیں'): ['ہوتا', 'ہوتا', 'ہوتا', 'ہوتا', 'ہوتا', 'ہوتا'],
#  ('نہیں', 'ہوتا'): ['\n', '\n', '\n', '\n', '\n', '\n'],
#  ('ہوتا', '\n'): ['صنم', 'گنو', 'جہان', 'ہر', 'رواں', 'کچھ', 'ہمیں'],
#  ('\n', 'صنم'): ['دکھلائیں'],
#  ('صنم', 'دکھلائیں'): ['گے'],
#  ('دکھلائیں', 'گے'): ['راہ'],
#  ('گے', 'راہ'): ['خدا'],
#  ('راہ', 'خدا'): ['ایسے'],
#  ('خدا', 'ایسے'): ['نہیں'],
#  ('\n', 'گنو'): ['سب', 'سب'],
#  ('گنو', 'سب'): ['حسرتیں', 'داغ'],
#  ('سب', 'حسرتیں'): ['جو'],
#  ('حسرتیں', 'جو'): ['خوں'],
#  ('جو', 'خوں'): ['ہوئی'],
#  ('خوں', 'ہوئی'): ['ہیں'],
#  ('ہوئی', 'ہیں'): ['تن', 'گھٹائیں', 'شمعیں'],
#  ('ہیں', 'تن'): ['کے'],
#  ('تن', 'کے'): ['مقتل', 'اس'],
#  ('کے', 'مقتل'): ['میں'],
#  ('مقتل', 'میں'): ['\n', 'گیا', 'کریں', 'اے', 'کچھ'],
#  ('\n', 'مرے'): ['قاتل',
#   'چارہ',
#   'ضبط',
#   'خیال',
#   'نزار',
#   'فگار',
#   'ماضی',
#   'وطن',
#   'چمن',
#   'دل،'],
#  ('مرے', 'قاتل'): ['حساب'],
#  ('قاتل', 'حساب'): ['خوں'],
#  ('حساب', 'خوں'): ['بہا'],
#  ('خوں', 'بہا'): ['ایسے', 'طلب'],
#  ('بہا', 'ایسے'): ['نہیں'],
#  ('\n', 'جہان'): ['دل'],
#  ('جہان', 'دل'): ['میں'],
#  ('میں', 'کام'): ['آتی', 'آیا'],
#  ('کام', 'آتی'): ['ہیں'],
#  ('آتی', 'ہیں'): ['تدبیریں'],
#  ('ہیں', 'تدبیریں'): ['نہ'],
#  ('تدبیریں', 'نہ'): ['تعزیریں'],
#  ('نہ', 'تعزیریں'): ['\n'],
#  ('تعزیریں', '\n'): ['یہاں'],
#  ('\n', 'یہاں'): ['پیمان', 'وابستگی'],
#  ('یہاں', 'پیمان'): ['تسلیم'],
#  ('پیمان', 'تسلیم'): ['و'],
#  ('تسلیم', 'و'): ['رضا'],
#  ('و', 'رضا'): ['ایسے'],
#  ('رضا', 'ایسے'): ['نہیں'],
#  ('\n', 'ہر'): ['اک',
#   'شخص',
#   'روش',
#   'صدا',
#   'صدا',
#   'قدم',
#   'اجنبی',
#   'ایک',
#   'اک',
#   'رگ',
#   'گھڑی',
#   'بادشہ',
#   'ایک',
#   'ایک',
#   'قدم',
#   'رہ',
#   'حقیقت',
#   'سمت',
#   'منزل',
#   'کوئی',
#   'گھڑی',
#   'جانب',
#   'اک',
#   'ویراں',
#   'غازی',
#   'دختر',
#   'راہ',
#   'مسرت',
#   'اک',
#   'ایک',
#   'اک',
#   'اک',
#   'اک',
#   'اک',
#   'ایک',
#   'ایک',
#   'ایک',
#   'ایک',
#   'اک',
#   'ایک',
#   'ایک',
#   'آئے',
#   'کاسۂ',
#   'صبح',
#   'پھول',
#   'بھیگی',
#   'راہ',
#   'حرف',
#   'اک',
#   'شب',
#   'صبح',
#   'درد',
#   'داغ',
#   'صنم',
#   'اک',
#   'سو',
#   'اک',
#   'شے',
#   'پربت',
#   'چال',
#   'بستے',
#   'چلتی'],
#  ('ہر', 'اک'): ['شب',
#   'مدعی',
#   'رنگ',
#   'قدم',
#   'گام',
#   'راہ',
#   'روز',
#   'راگ',
#   'پردۂ',
#   'نگاہ',
#   'رگ',
#   'بن',
#   'باب',
#   'درد',
#   'زخم',
#   'ظلم',
#   'ظلم',
#   'اولی',
#   'مقام',
#   'سے',
#   'بوند',
#   'کشید',
#   'میں',
#   'کے',
#   'ہمدم',
#   'سمت',
#   'اجنبی',
#   'غم',
#   'دور',
#   'پیڑ',
#   'در',
#   'جانب'],
#  ('اک', 'شب'): ['ہر'],
#  ('شب', 'ہر'): ['گھڑی'],
#  ('ہر', 'گھڑی'): ['گزرے', 'ہم', 'سایہ'],
#  ('گھڑی', 'گزرے'): ['قیامت'],
#  ('گزرے', 'قیامت'): ['یوں'],
#  ('قیامت', 'یوں'): ['تو'],
#  ('یوں', 'تو'): ['ہوتا'],
#  ('تو', 'ہوتا'): ['ہے'],
#  ('ہوتا', 'ہے'): ['\n', 'گھر', 'حریف', 'حریف', 'بازو'],
#  ('\n', 'مگر'): ['ہر', 'دل', 'یہ', 'یہ', 'پھر', 'یہ', 'وہ'],
#  ('مگر', 'ہر'): ['صبح'],
#  ('ہر', 'صبح'): ['ہو', 'پر', 'گلستاں', 'کی'],
#  ('صبح', 'ہو'): ['روز'],
#  ('ہو', 'روز'): ['جزا'],
#  ('روز', 'جزا'): ['ایسے', 'گیا'],
#  ('جزا', 'ایسے'): ['نہیں'],
#  ('\n', 'رواں'): ['ہے', 'ہو', 'رہے'],
#  ('رواں', 'ہے'): ['نبض', 'وہی'],
#  ('ہے', 'نبض'): ['دوراں'],
#  ('نبض', 'دوراں'): ['گردشوں'],
#  ('دوراں', 'گردشوں'): ['میں'],
#  ('گردشوں', 'میں'): ['آسماں'],
#  ('میں', 'آسماں'): ['سارے', 'ہے'],
#  ('آسماں', 'سارے'): ['\n'],
#  ('سارے', '\n'): ['جو',
#   'جتنے',
#   'جو',
#   'جو',
#   'ملال',
#   'ترے',
#   'بہار',
#   'آج',
#   'تھمتے'],
#  ('\n', 'جو'): ['تم',
#   'بچے',
#   'وہ',
#   'کہا',
#   'رکے',
#   'نفس',
#   'طلب',
#   'نہ',
#   'اب',
#   'تمہاری',
#   'آئے',
#   'دل',
#   'دل',
#   'قاتل',
#   'بھی',
#   'خندہ',
#   'ذرا',
#   'گاہ',
#   'چل',
#   'خار',
#   'گزرتے',
#   'بھی',
#   'ہم',
#   'کوئے',
#   'شے',
#   'ترے',
#   'کچھ',
#   'ان',
#   'عزم',
#   'کج',
#   'اہل',
#   'اپنے',
#   'حرف',
#   'حسرتیں',
#   'دیکھنا',
#   'آئنے',
#   'چہرے',
#   'تیرے',
#   'مٹ',
#   'تیری',
#   'تیرے',
#   'اک',
#   'دریا',
#   'کچھ',
#   'مل',
#   'پہلا',
#   'ہونا',
#   'ہوگا',
#   'رات',
#   'پھول',
#   'پتا',
#   'کوئی',
#   'ترے',
#   'اس',
#   'بھی',
#   'برف',
#   'زیر',
#   'ٹوٹ',
#   'ٹوٹ',
#   'مے',
#   'ہاتھ',
#   'آنکھ'],
#  ('جو', 'تم'): ['کہتے'],
#  ('تم', 'کہتے'): ['ہو'],
#  ('کہتے', 'ہو'): ['سب', 'وہ', 'وہ', 'اب'],
#  ('ہو', 'سب'): ['کچھ'],
#  ('سب', 'کچھ'): ['ہو', 'نثار', 'لٹا', 'برملا'],
#  ('کچھ', 'ہو'): ['چکا'],
#  ('ہو', 'چکا'): ['ایسے', 'عشق', 'ختم'],
#  ('چکا', 'ایسے'): ['نہیں'],
#  ('\n', 'کچھ'): ['پہلے',
#   'امتحان',
#   'ان',
#   'اپنے',
#   'ہمیں',
#   'دل',
#   'کہتی',
#   'روشنی',
#   'بھی',
#   'دن',
#   'محتسبوں',
#   'تو',
#   'اپنی',
#   'حشر',
#   'ان',
#   'مانجھی',
#   'بے',
#   'اتنے',
#   'الجھی',
#   'اشک',
#   'گلے',
#   'آزادی',
#   'لوگ',
#   'وہ',
#   'اب'],
#  ('کچھ', 'پہلے'): ['ان'],
#  ('پہلے', 'ان'): ['آنکھوں'],
#  ('ان', 'آنکھوں'): ['آگے', 'نے', 'نے', 'سے'],
#  ('آنکھوں', 'آگے'): ['کیا'],
#  ('آگے', 'کیا'): ['کیا'],
#  ('کیا', 'کیا'): ['نہ',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'باب',
#   'ہمیں',
#   'نہ',
#   'نہ'],
#  ('کیا', 'نہ'): ['نظارا', 'سہا', 'کیا', 'تجھے', 'دل'],
#  ('نہ', 'نظارا'): ['گزرے'],
#  ('نظارا', 'گزرے'): ['تھا'],
#  ('گزرے', 'تھا'): ['\n', '\n', '\n', '\n', '\n', '\n'],
#  ('تھا', '\n'): ['کیا',
#   'تھے',
#   'اب',
#   'تھی',
#   'اب',
#   'کس',
#   'یہ',
#   'گلیوں',
#   'منزل',
#   'تھک',
#   'واعظ',
#   'نہ',
#   'وہ',
#   'اب',
#   'مہلت',
#   'نہ',
#   'بصد',
#   'اور',
#   'ساز',
#   'اپنے',
#   'شوق',
#   'چشم',
#   'جلوۂ',
#   'جب',
#   'میری',
#   'اس',
#   'جس',
#   'آشنا',
#   'دیس',
#   'اپنی'],
#  ('\n', 'کیا'): ['روشن',
#   'بھی',
#   'کریں',
#   'خبر',
#   'ہوا',
#   'کیجیے',
#   'جانے',
#   'رکھا',
#   'کیجیے',
#   'ہے',
#   'خوف',
#   'خوف',
#   'یہی',
#   'ہے',
#   'کیا',
#   'آس',
#   'آس'],
#  ('کیا', 'روشن'): ['ہو'],
#  ('روشن', 'ہو'): ['جاتی'],
#  ('ہو', 'جاتی'): ['تھی'],
#  ('جاتی', 'تھی'): ['گلی'],
#  ('تھی', 'گلی'): ['جب'],
#  ('گلی', 'جب'): ['یار'],
#  ('جب', 'یار'): ['ہمارا'],
#  ('یار', 'ہمارا'): ['گزرے'],
#  ('ہمارا', 'گزرے'): ['تھا'],
#  ('\n', 'تھے'): ['کتنے', 'خاک', 'شب', 'بزم', 'بہت'],
#  ('تھے', 'کتنے'): ['اچھے'],
#  ('کتنے', 'اچھے'): ['لوگ'],
#  ('اچھے', 'لوگ'): ['کہ'],
#  ('لوگ', 'کہ'): ['جن'],
#  ('کہ', 'جن'): ['کو', 'سے'],
#  ('جن', 'کو'): ['اپنے'],
#  ('کو', 'اپنے'): ['غم'],
#  ('اپنے', 'غم'): ['سے'],
#  ('غم', 'سے'): ['فرصت', '\n', 'تری'],
#  ('سے', 'فرصت'): ['تھی'],
#  ('فرصت', 'تھی'): ['\n'],
#  ('تھی', '\n'): ['سب',
#   'سو',
#   'کیا',
#   'ہجر',
#   'آج',
#   'ہم',
#   'تم',
#   'تھا',
#   'یوں',
#   'وہ',
#   'اب',
#   'جام',
#   'صہبائے'],
#  ('سب', 'پوچھیں'): ['تھے'],
#  ('پوچھیں', 'تھے'): ['احوال'],
#  ('تھے', 'احوال'): ['جو'],
#  ('احوال', 'جو'): ['کوئی'],
#  ('جو', 'کوئی'): ['درد', 'پوچھے', 'شمار'],
#  ('کوئی', 'درد'): ['کا'],
#  ('درد', 'کا'): ['مارا',
#   'بادل',
#   'رشتہ',
#   'ہنگام',
#   'ڈیرا',
#   'دوشالہ',
#   'ستارا',
#   'اب',
#   'اب'],
#  ('کا', 'مارا'): ['گزرے'],
#  ('مارا', 'گزرے'): ['تھا'],
#  ('\n', 'اب'): ['کے',
#   'تو',
#   'نہیں',
#   'کسی',
#   'احتیاط',
#   'اپنا',
#   'جو',
#   'کے',
#   'وہی',
#   'وہی',
#   'جنوں',
#   'طبیعت',
#   'شہر',
#   'وہی',
#   'جہاں',
#   'کے',
#   'شہر',
#   'وہ',
#   'کوچۂ',
#   'بھی',
#   'نہ',
#   'ان',
#   'آ',
#   'دور',
#   'بھی',
#   'بے',
#   'التفات',
#   'بزم',
#   'حلقۂ',
#   'صاحب',
#   'شہر',
#   'ان',
#   'ان',
#   'مری',
#   'ٹوٹ',
#   'کیوں',
#   'کیوں',
#   'جو',
#   'جتنے',
#   'تم',
#   'کیسے',
#   'جو',
#   'جتنے',
#   'تم',
#   'نہ',
#   'نہ',
#   'نہ',
#   'فقیہان',
#   'کسی',
#   'کوئی',
#   'کسی',
#   'کوئی',
#   'وہ',
#   'سیر',
#   'چمکے',
#   'جاگو',
#   'جاگو',
#   'جاگو',
#   'وقت',
#   'قاتل',
#   'رسم',
#   'صدیوں',
#   'کوئی',
#   'کوئی',
#   'کوئی',
#   'کبھی',
#   'کبھی',
#   'بادل',
#   'سعی',
#   'اور'],
#  ('اب', 'کے'): ['خزاں',
#   'بہ',
#   'برکھا',
#   'مئے',
#   'برس',
#   'برس',
#   'بہار',
#   'بھی',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'اور'],
#  ('کے', 'خزاں'): ['ایسی'],
#  ('خزاں', 'ایسی'): ['ٹھہری'],
#  ('ایسی', 'ٹھہری'): ['وہ'],
#  ('ٹھہری', 'وہ'): ['سارے'],
#  ('وہ', 'سارے'): ['زمانے', 'عنواں'],
#  ('سارے', 'زمانے'): ['بھول'],
#  ('زمانے', 'بھول'): ['گئے'],
#  ('بھول', 'گئے'): ['\n'],
#  ('گئے', '\n'): ['جب',
#   'رہ',
#   'تری',
#   'تری',
#   'نہ',
#   'یہ',
#   'نہ',
#   'تم',
#   'جس',
#   'ہاتھ',
#   'ان',
#   'جس',
#   'یوں',
#   'سو',
#   'اب',
#   'بات',
#   'دوستو،',
#   'خون',
#   'ہر'],
#  ('\n', 'جب'): ['موسم',
#   'مل',
#   'چاہا',
#   'بھی',
#   'صبا',
#   'بہاروں',
#   'سے',
#   'تلک',
#   'ستانے',
#   'وہ',
#   'درد',
#   'سورج',
#   'سے',
#   'خوں',
#   'سے',
#   'تخت',
#   'دل',
#   'دل',
#   'دکھ',
#   'اپنی',
#   'تیری',
#   'بھی',
#   'تک',
#   'فکر',
#   'کہیں',
#   'کبھی',
#   'خون',
#   'شعر',
#   'کنج'],
#  ('جب', 'موسم'): ['گل'],
#  ('موسم', 'گل'): ['ہر', 'ہے', 'گرچہ', 'کے', 'اس'],
#  ('گل', 'ہر'): ['پھیرے'],
#  ('ہر', 'پھیرے'): ['میں'],
#  ('پھیرے', 'میں'): ['آ'],
#  ('میں', 'آ'): ['آ', 'کے', 'گرے', 'رہوں', 'کے'],
#  ('آ', 'آ'): ['کے', 'کے'],
#  ('آ', 'کے'): ['دوبارا',
#   'چلا',
#   'دیکھ',
#   'کیا',
#   'دی',
#   'رکتے',
#   'بیٹھے',
#   'صدا',
#   'کرے',
#   'کرتا',
#   'ابھی'],
#  ('کے', 'دوبارا'): ['گزرے'],
#  ('دوبارا', 'گزرے'): ['تھا'],
#  ('\n', 'تھی'): ['یاروں', 'مگر'],
#  ('تھی', 'یاروں'): ['کی'],
#  ('یاروں', 'کی'): ['بہتات', 'کس'],
#  ('کی', 'بہتات'): ['تو'],
#  ('بہتات', 'تو'): ['ہم'],
#  ('تو', 'ہم'): ['اغیار', 'سے', 'بھی'],
#  ('ہم', 'اغیار'): ['سے'],
#  ('اغیار', 'سے'): ['بھی'],
#  ('سے', 'بھی'): ['بیزار'],
#  ('بھی', 'بیزار'): ['نہ'],
#  ('بیزار', 'نہ'): ['تھے'],
#  ('نہ', 'تھے'): ['\n', 'جاں', '\n'],
#  ('تھے', '\n'): ['جب',
#   'ہر',
#   'ہم',
#   'رنگ',
#   'تیرے',
#   'جب',
#   'میرے',
#   'عمر',
#   'ہمت',
#   'جو',
#   'اب',
#   'جو',
#   'ہوس',
#   'جو',
#   'نکھر',
#   'ان',
#   'یہ',
#   'تھا',
#   'یوں',
#   'وید',
#   'ناداری',
#   'تاجر'],
#  ('جب', 'مل'): ['بیٹھے'],
#  ('مل', 'بیٹھے'): ['تو'],
#  ('بیٹھے', 'تو'): ['دشمن'],
#  ('تو', 'دشمن'): ['کا'],
#  ('دشمن', 'کا'): ['بھی', 'نرغہ'],
#  ('کا', 'بھی'): ['ساتھ', 'شکرانہ', 'تمہیں', 'کوئی'],
#  ('بھی', 'ساتھ'): ['گوارا'],
#  ('ساتھ', 'گوارا'): ['گزرے'],
#  ('گوارا', 'گزرے'): ['تھا'],
#  ('اب', 'تو'): ['ہاتھ'],
#  ('تو', 'ہاتھ'): ['سجھائی', 'آئی'],
#  ('ہاتھ', 'سجھائی'): ['نہ'],
#  ('سجھائی', 'نہ'): ['دیوے'],
#  ('نہ', 'دیوے'): ['لیکن'],
#  ('دیوے', 'لیکن'): ['اب'],
#  ('لیکن', 'اب'): ['سے'],
#  ('اب', 'سے'): ['پہلے', 'پہلے'],
#  ('سے', 'پہلے'): ['تو',
#   'بھی',
#   '\n',
#   'عتاب',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n'],
#  ('پہلے', 'تو'): ['\n', 'نہ'],
#  ('تو', '\n'): ['آنکھ', 'سکوں'],
#  ('\n', 'آنکھ'): ['اٹھتے', 'سے', 'گوہر'],
#  ('آنکھ', 'اٹھتے'): ['ہی'],
#  ('اٹھتے', 'ہی'): ['ایک'],
#  ('ہی', 'ایک'): ['نظر'],
#  ('ایک', 'نظر'): ['میں'],
#  ('میں', 'عالم'): ['سارا'],
#  ('عالم', 'سارا'): ['گزرے'],
#  ('سارا', 'گزرے'): ['تھا'],
#  ('کس', 'حرف'): ['پہ'],
#  ('حرف', 'پہ'): ['تو'],
#  ('پہ', 'تو'): ['نے'],
#  ('تو', 'نے'): ['گوشۂ', '\n', '\n', 'دیکھی'],
#  ('نے', 'گوشۂ'): ['لب'],
#  ('گوشۂ', 'لب'): ['اے'],
#  ('لب', 'اے'): ['جان'],
#  ('اے', 'جان'): ['جہاں', 'جاں'],
#  ('جان', 'جہاں'): ['غماز', 'کو'],
#  ('جہاں', 'غماز'): ['کیا'],
#  ('غماز', 'کیا'): ['\n'],
#  ('کیا', '\n'): ['اعلان',
#   'سو',
#   'بے',
#   'جس',
#   'لو',
#   'کس',
#   'جدا',
#   'پہنچ',
#   'ہم',
#   'ستم',
#   'نہ',
#   'پھر',
#   'غم',
#   'تھے',
#   'خوشا',
#   'وہ',
#   'یک',
#   'نہ',
#   'جنہیں',
#   'اتنا',
#   'اس',
#   'شور',
#   'جس',
#   'یہ',
#   'افسردہ',
#   'اس'],
#  ('\n', 'اعلان'): ['جنوں'],
#  ('اعلان', 'جنوں'): ['دل'],
#  ('جنوں', 'دل'): ['والوں'],
#  ('دل', 'والوں'): ['نے'],
#  ('والوں', 'نے'): ['اب', '\n', 'تم'],
#  ('نے', 'اب'): ['کے', 'تک'],
#  ('کے', 'بہ'): ['ہزار'],
#  ('بہ', 'ہزار'): ['انداز'],
#  ('ہزار', 'انداز'): ['کیا'],
#  ('انداز', 'کیا'): ['\n'],
#  ('\n', 'سو'): ['پیکاں',
#   'تیر',
#   'کر',
#   'بار',
#   'رستے',
#   'طرح',
#   'بار',
#   'بار',
#   'رہی'],
#  ('سو', 'پیکاں'): ['تھے'],
#  ('پیکاں', 'تھے'): ['پیوست'],
#  ('تھے', 'پیوست'): ['گلو'],
#  ('پیوست', 'گلو'): ['جب'],
#  ('گلو', 'جب'): ['چھیڑی'],
#  ('جب', 'چھیڑی'): ['شوق'],
#  ('چھیڑی', 'شوق'): ['کی'],
#  ('شوق', 'کی'): ['لے', 'ماند', 'ترسی'],
#  ('کی', 'لے'): ['ہم', 'تیز'],
#  ('لے', 'ہم'): ['نے'],
#  ('سو', 'تیر'): ['ترازو'],
#  ('تیر', 'ترازو'): ['تھے'],
#  ('ترازو', 'تھے'): ['دل'],
#  ('تھے', 'دل'): ['میں', 'کے'],
#  ('میں', 'جب'): ['ہم', 'اک', 'نظر', 'پھر'],
#  ('جب', 'ہم'): ['نے', 'بھی'],
#  ('نے', 'رقص'): ['آغاز'],
#  ('رقص', 'آغاز'): ['کیا'],
#  ('آغاز', 'کیا'): ['\n'],
#  ('\n', 'بے'): ['حرص',
#   'طلب',
#   'سبب',
#   'پیے',
#   'دم',
#   'نشاں',
#   'محبت',
#   'سبب',
#   'زباں',
#   'درد',
#   'خوابیاں',
#   'طلب',
#   'التفات',
#   'رحم'],
#  ('بے', 'حرص'): ['و'],
#  ('حرص', 'و'): ['ہوا'],
#  ('و', 'ہوا'): ['بے', 'ہے'],
#  ('ہوا', 'بے'): ['خوف'],
#  ('بے', 'خوف'): ['و'],
#  ('خوف', 'و'): ['خطر', 'خطر'],
#  ('و', 'خطر'): ['اس', 'سے'],
#  ('خطر', 'اس'): ['ہاتھ'],
#  ('اس', 'ہاتھ'): ['پہ'],
#  ('ہاتھ', 'پہ'): ['سر', 'ہے'],
#  ('پہ', 'سر'): ['اس', 'کفن'],
#  ('سر', 'اس'): ['کف'],
#  ('اس', 'کف'): ['پہ', 'نازنیں'],
#  ('کف', 'پہ'): ['جگر', 'لیے'],
#  ('پہ', 'جگر'): ['\n'],
#  ('جگر', '\n'): ['یوں'],
#  ('\n', 'یوں'): ['کوئے',
#   'سجا',
#   'فضا',
#   'بہار',
#   'عرض',
#   'ٹوٹ',
#   'پیر',
#   'بہار',
#   'پاؤں',
#   'خاک',
#   'کوچہ',
#   'پاؤں',
#   'لگتا',
#   'لگتا',
#   'ہے',
#   'گماں',
#   'ٹکڑے',
#   'عمر'],
#  ('یوں', 'کوئے'): ['صنم'],
#  ('کوئے', 'صنم'): ['میں'],
#  ('صنم', 'میں'): ['وقت'],
#  ('میں', 'وقت'): ['سفر'],
#  ('وقت', 'سفر'): ['نظارۂ'],
#  ('سفر', 'نظارۂ'): ['بام'],
#  ('نظارۂ', 'بام'): ['ناز'],
#  ('بام', 'ناز'): ['کیا'],
#  ('ناز', 'کیا'): ['\n'],
#  ('جس', 'خاک'): ['میں'],
#  ('خاک', 'میں'): ['مل', 'ریزہ', 'کیف', 'غلطاں', 'ڈھونڈھتا'],
#  ('میں', 'مل'): ['کر'],
#  ('مل', 'کر'): ['خاک', 'جیو', 'سر', '\n'],
#  ('کر', 'خاک'): ['ہوئے'],
#  ('خاک', 'ہوئے'): ['وہ'],
#  ('ہوئے', 'وہ'): ['سرمۂ'],
#  ('وہ', 'سرمۂ'): ['چشم'],
#  ('سرمۂ', 'چشم'): ['خلق'],
#  ('چشم', 'خلق'): ['بنی'],
#  ('خلق', 'بنی'): ['\n'],
#  ('بنی', '\n'): ['جس'],
#  ('جس', 'خار'): ['پہ'],
#  ('خار', 'پہ'): ['ہم'],
#  ('پہ', 'ہم'): ['نے', 'روزگار', '\n'],
#  ('نے', 'خوں'): ['چھڑکا'],
#  ('خوں', 'چھڑکا'): ['ہم'],
#  ('چھڑکا', 'ہم'): ['رنگ'],
#  ('ہم', 'رنگ'): ['گل'],
#  ('رنگ', 'گل'): ['طناز'],
#  ('گل', 'طناز'): ['کیا'],
#  ('طناز', 'کیا'): ['\n'],
#  ('\n', 'لو'): ['وصل', 'سنی', 'دے', 'شوق', 'ڈوب'],
#  ('لو', 'وصل'): ['کی'],
#  ('وصل', 'کی'): ['ساعت', 'شب', 'سر'],
#  ('کی', 'ساعت'): ['آ', '\n', '\n'],
#  ('ساعت', 'آ'): ['پہنچی'],
#  ('آ', 'پہنچی'): ['پھر'],
#  ('پہنچی', 'پھر'): ['حکم'],
#  ('پھر', 'حکم'): ['حضوری'],
#  ('حکم', 'حضوری'): ['پر'],
#  ('حضوری', 'پر'): ['ہم'],
#  ('پر', 'ہم'): ['نے'],
#  ('\n', 'آنکھوں'): ['کے', 'میں', 'کے', 'سے'],
#  ('آنکھوں', 'کے'): ['دریچے', 'دریچوں', 'گل', '\n', 'گم', 'شب'],
#  ('کے', 'دریچے'): ['بند'],
#  ('دریچے', 'بند'): ['کیے'],
#  ('بند', 'کیے'): ['اور'],
#  ('کیے', 'اور'): ['سینے'],
#  ('اور', 'سینے'): ['کا'],
#  ('سینے', 'کا'): ['در'],
#  ('کا', 'در'): ['باز'],
#  ('در', 'باز'): ['کیا'],
#  ('باز', 'کیا'): ['\n'],
#  ('کس', 'شہر'): ['نہ'],
#  ('شہر', 'نہ'): ['شہرہ'],
#  ('نہ', 'شہرہ'): ['ہوا'],
#  ('شہرہ', 'ہوا'): ['نادانئ'],
#  ('ہوا', 'نادانئ'): ['دل'],
#  ('نادانئ', 'دل'): ['کا'],
#  ('دل', 'کا'): ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'ہر',
#   'عالم',
#   '\n',
#   'نہ',
#   'مدعا',
#   'جو',
#   'صلہ',
#   'نصیبہ',
#   'کچھ'],
#  ('کس', 'پر'): ['نہ', 'ہو', 'ہجر'],
#  ('پر', 'نہ'): ['کھلا'],
#  ('نہ', 'کھلا'): ['راز'],
#  ('کھلا', 'راز'): ['پریشانئ'],
#  ('راز', 'پریشانئ'): ['دل'],
#  ('پریشانئ', 'دل'): ['کا'],
#  ('\n', 'آؤ'): ['کریں', 'اک', 'ببر'],
#  ('آؤ', 'کریں'): ['محفل'],
#  ('کریں', 'محفل'): ['پہ'],
#  ('محفل', 'پہ'): ['زر'],
#  ('پہ', 'زر'): ['زخم'],
#  ('زر', 'زخم'): ['نمایاں'],
#  ('زخم', 'نمایاں'): ['\n'],
#  ('نمایاں', '\n'): ['چرچا'],
#  ('\n', 'چرچا'): ['ہے'],
#  ('چرچا', 'ہے'): ['بہت'],
#  ('ہے', 'بہت'): ['بے', 'زیادہ', 'لطف'],
#  ('بہت', 'بے'): ['سر', 'درد', 'مہر'],
#  ('بے', 'سر'): ['و'],
#  ('سر', 'و'): ['سامانئ'],
#  ('و', 'سامانئ'): ['دل'],
#  ('سامانئ', 'دل'): ['کا'],
#  ('\n', 'دیکھ'): ['آئیں', 'آئیں'],
#  ('دیکھ', 'آئیں'): ['چلو', 'چلو'],
#  ('آئیں', 'چلو'): ['کوئے', 'ہم'],
#  ('چلو', 'کوئے'): ['نگاراں'],
#  ('کوئے', 'نگاراں'): ['کا'],
#  ('نگاراں', 'کا'): ['خرابہ'],
#  ('کا', 'خرابہ'): ['\n'],
#  ('خرابہ', '\n'): ['شاید'],
#  ('\n', 'شاید'): ['کوئی',
#   'قریب',
#   'اپنا',
#   'مری',
#   'مری',
#   'مری',
#   'تم',
#   'اس',
#   'اس',
#   'اس',
#   'کہ'],
#  ('شاید', 'کوئی'): ['محرم'],
#  ('کوئی', 'محرم'): ['ملے'],
#  ('محرم', 'ملے'): ['ویرانئ'],
#  ('ملے', 'ویرانئ'): ['دل'],
#  ('ویرانئ', 'دل'): ['کا', 'کھانے'],
#  ('\n', 'پوچھو'): ['تو'],
#  ('پوچھو', 'تو'): ['ادھر'],
#  ('تو', 'ادھر'): ['تیر'],
#  ('ادھر', 'تیر'): ['فگن'],
#  ('تیر', 'فگن'): ['کون'],
#  ('فگن', 'کون'): ['ہے'],
#  ('کون', 'ہے'): ['یارو', '\n', '\n', '\n'],
#  ('ہے', 'یارو'): ['\n', 'صبا'],
#  ('یارو', '\n'): ['سونپا', 'کچھ'],
#  ('\n', 'سونپا'): ['تھا'],
#  ('سونپا', 'تھا'): ['جسے'],
#  ('تھا', 'جسے'): ['کام', 'سب'],
#  ('جسے', 'کام'): ['نگہبانئ'],
#  ('کام', 'نگہبانئ'): ['دل'],
#  ('نگہبانئ', 'دل'): ['کا'],
#  ('\n', 'دیکھو'): ['تو', 'آئی', 'کتنا'],
#  ('دیکھو', 'تو'): ['کدھر', 'سہی'],
#  ('تو', 'کدھر'): ['آج'],
#  ('کدھر', 'آج'): ['رخ'],
#  ('آج', 'رخ'): ['باد'],
#  ('رخ', 'باد'): ['صبا'],
#  ('صبا', 'ہے'): ['\n', '\n'],
#  ('کس', 'رہ'): ['سے', 'چلتے'],
#  ('رہ', 'سے'): ['پیام'],
#  ('سے', 'پیام'): ['آیا'],
#  ('پیام', 'آیا'): ['ہے'],
#  ('آیا', 'ہے'): ['زندانئ', '\n', 'اب'],
#  ('ہے', 'زندانئ'): ['دل'],
#  ('زندانئ', 'دل'): ['کا'],
#  ('\n', 'اترے'): ['تھے'],
#  ('اترے', 'تھے'): ['کبھی'],
#  ('تھے', 'کبھی'): ['فیضؔ'],
#  ('کبھی', 'فیضؔ'): ['وہ'],
#  ('فیضؔ', 'وہ'): ['آئینۂ'],
#  ('وہ', 'آئینۂ'): ['دل'],
#  ('آئینۂ', 'دل'): ['میں', 'کو', 'گداز'],
#  ('\n', 'عالم'): ['ہے', 'میں'],
#  ('عالم', 'ہے'): ['وہی'],
#  ('ہے', 'وہی'): ['آج',
#   'فصل',
#   'بات',
#   'عارض',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'تن',
#   'انتظار'],
#  ('وہی', 'آج'): ['بھی'],
#  ('آج', 'بھی'): ['حیرانئ'],
#  ('بھی', 'حیرانئ'): ['دل'],
#  ('حیرانئ', 'دل'): ['کا'],
#  ('\n', 'گو'): ['سب'],
#  ('گو', 'سب'): ['کو'],
#  ('سب', 'کو'): ['بہم', 'خفا'],
#  ('کو', 'بہم'): ['ساغر'],
#  ('بہم', 'ساغر'): ['و'],
#  ('ساغر', 'و'): ['بادہ', 'جام'],
#  ('و', 'بادہ'): ['تو'],
#  ('بادہ', 'تو'): ['نہیں'],
#  ('تو', 'نہیں'): ['تھا',
#   'تھا',
#   'تھا',
#   'تھا',
#   'تھا',
#   'تھا',
#   'ہے',
#   '\n',
#   'ناکام',
#   '\n',
#   'پاس'],
#  ('نہیں', 'تھا'): ['\n', '\n', '\n', '\n', '\n', '\n'],
#  ('\n', 'یہ'): ['شہر',
#   'کس',
#   'جفائے',
#   'عجب',
#   'سخن',
#   'مزار',
#   'جو',
#   'جان',
#   'عہد',
#   'ہمیں',
#   'صبر',
#   'میرا',
#   'خون',
#   'ضد',
#   'آ',
#   'ندیم',
#   'فرق',
#   'نظر',
#   'جامۂ',
#   'تیغ',
#   'برہمن',
#   'موسم',
#   'نہ',
#   'گیت',
#   'آزمائش',
#   'شعر',
#   'گراں',
#   'کون',
#   'کون',
#   'لکھ',
#   'طفل',
#   'زیست',
#   'امن',
#   'شہر',
#   'شہر',
#   'کیسی',
#   'مہندی',
#   'راہیں',
#   'کیسی',
#   'کیسی',
#   'دن',
#   'دن',
#   'گھاؤ',
#   'مری',
#   'دھوپ',
#   'میل',
#   'اپنا',
#   'اپنا',
#   'گھڑی',
#   'جو',
#   'تو',
#   'چلا',
#   'کڑی',
#   'زہر',
#   'بھرا',
#   'تیرا',
#   'بزم',
#   'ساز',
#   'ہاتھ',
#   'شام',
#   'لوح',
#   'ساغر',
#   'رنگیں',
#   'کانچ',
#   'ساغر',
#   'ساغر',
#   'پردے',
#   'کالک',
#   'آگ',
#   'رقص',
#   'دل'],
#  ('یہ', 'شہر'): ['اداس', 'ازل', 'ابد'],
#  ('شہر', 'اداس'): ['اتنا'],
#  ('اداس', 'اتنا'): ['زیادہ'],
#  ('اتنا', 'زیادہ'): ['تو', 'تو'],
#  ('زیادہ', 'تو'): ['نہیں', 'نہیں'],
#  ('\n', 'گلیوں'): ['میں', 'میں', 'میں'],
#  ('گلیوں', 'میں'): ['پھرا', 'لیے', 'کسی', 'ہو'],
#  ('میں', 'پھرا'): ['کرتے', 'کرتے'],
#  ('پھرا', 'کرتے'): ['تھے', 'ہیں'],
#  ('کرتے', 'تھے'): ['دو', 'سر', 'لہو', '\n'],
#  ('تھے', 'دو'): ['چار'],
#  ('دو', 'چار'): ['دوانے', 'نہ'],
#  ('چار', 'دوانے'): ['\n'],
#  ('دوانے', '\n'): ['ہر'],
#  ('ہر', 'شخص'): ['کا'],
#  ('شخص', 'کا'): ['صد'],
#  ('کا', 'صد'): ['چاک'],
#  ('صد', 'چاک'): ['لبادہ', 'بدل'],
#  ('چاک', 'لبادہ'): ['تو'],
#  ('لبادہ', 'تو'): ['نہیں'],
#  ('\n', 'منزل'): ['کو'],
#  ('منزل', 'کو'): ['نہ'],
#  ('کو', 'نہ'): ['پہچانے', 'جس'],
#  ('نہ', 'پہچانے'): ['رہ'],
#  ('پہچانے', 'رہ'): ['عشق'],
#  ('رہ', 'عشق'): ['کا', 'میں'],
#  ('عشق', 'کا'): ['راہی', 'بانکپن', 'راز'],
#  ('کا', 'راہی'): ['\n'],
#  ('راہی', '\n'): ['ناداں'],
#  ('\n', 'ناداں'): ['ہی'],
#  ('ناداں', 'ہی'): ['سہی'],
#  ('ہی', 'سہی'): ['ایسا',
#   '\n',
#   'اتنے',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'شور',
#   '\n',
#   'بانگ',
#   '\n'],
#  ('سہی', 'ایسا'): ['بھی'],
#  ('ایسا', 'بھی'): ['سادہ'],
#  ('بھی', 'سادہ'): ['تو'],
#  ('سادہ', 'تو'): ['نہیں'],
#  ('\n', 'تھک'): ['کر', 'جائیں', 'کر'],
#  ('تھک', 'کر'): ['یوں', 'ہر'],
#  ('کر', 'یوں'): ['ہی', 'ہی'],
#  ('یوں', 'ہی'): ['پل', 'دم', 'پل', 'بجھ', 'بسر', 'پذیرائی', 'مصروف', 'زندگی'],
#  ('ہی', 'پل'): ['بھر', 'بھر'],
#  ('پل', 'بھر'): ['کے', 'کو', 'کو', 'میں'],
#  ('بھر', 'کے'): ['لیے', 'گلاب'],
#  ('کے', 'لیے'): ['آنکھ',
#   'مرنا',
#   'جینا',
#   'اس',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   'ان'],
#  ('لیے', 'آنکھ'): ['لگی'],
#  ('آنکھ', 'لگی'): ['تھی'],
#  ('لگی', 'تھی'): ['\n', 'ورنہ', 'پہلے'],
#  ('سو', 'کر'): ['ہی'],
#  ('کر', 'ہی'): ['نہ'],
#  ('ہی', 'نہ'): ['اٹھیں', 'دی', 'دی'],
#  ('نہ', 'اٹھیں'): ['یہ'],
#  ('اٹھیں', 'یہ'): ['ارادہ'],
#  ('یہ', 'ارادہ'): ['تو'],
#  ('ارادہ', 'تو'): ['نہیں'],
#  ('\n', 'واعظ'): ['سے', 'ہے'],
#  ('واعظ', 'سے'): ['رہ'],
#  ('سے', 'رہ'): ['و'],
#  ('رہ', 'و'): ['رسم'],
#  ('و', 'رسم'): ['رہی'],
#  ('رسم', 'رہی'): ['رند'],
#  ('رہی', 'رند'): ['سے'],
#  ('رند', 'سے'): ['صحبت'],
#  ('سے', 'صحبت'): ['\n'],
#  ('صحبت', '\n'): ['فرق'],
#  ('\n', 'فرق'): ['ان', 'خورشید'],
#  ('فرق', 'ان'): ['میں'],
#  ('ان', 'میں'): ['کوئی', 'تیرا', 'لہو', 'ہر', 'الجھ'],
#  ('میں', 'کوئی'): ['اتنا', 'گلا'],
#  ('کوئی', 'اتنا'): ['زیادہ'],
#  ('\n', 'نہ'): ['اب',
#   'گنواؤ',
#   'وہ',
#   'ہوا',
#   'کسی',
#   'جانے',
#   'جانے',
#   'جانے',
#   'گئی',
#   'گئی',
#   'شب',
#   'سوال',
#   'رہا',
#   'گل',
#   'کسی',
#   'کرم',
#   'وہ',
#   'یہ',
#   'تن',
#   'ہم',
#   'پوچھو',
#   'دل',
#   'اس',
#   'قحط',
#   'اب',
#   'اب',
#   'خون',
#   'لیلائے',
#   'غم',
#   'شب'],
#  ('نہ', 'اب'): ['رقیب', 'ہم', 'مل'],
#  ('اب', 'رقیب'): ['نہ'],
#  ('رقیب', 'نہ'): ['ناصح'],
#  ('نہ', 'ناصح'): ['نہ'],
#  ('ناصح', 'نہ'): ['غم'],
#  ('نہ', 'غم'): ['گسار', 'ہائے'],
#  ('غم', 'گسار'): ['کوئی', 'چلے', 'چلے', 'کی', 'کو', 'کسے؟'],
#  ('گسار', 'کوئی'): ['\n'],
#  ('کوئی', '\n'): ['تم',
#   'کوچۂ',
#   'تو',
#   'داغ',
#   'دل',
#   'حرف',
#   'دوسرے',
#   'غزل',
#   'گویا',
#   'نقد',
#   'مصرع',
#   'ایسے'],
#  ('\n', 'تم'): ['آشنا',
#   'کوئی',
#   'آ',
#   'ستم',
#   'اچھے',
#   'آئے',
#   'اس',
#   'لاکھ',
#   'سے',
#   'اگر',
#   'سے',
#   'اپنے',
#   'جو',
#   'دل',
#   'خوف',
#   'اپنی',
#   'یہ',
#   'یہ',
#   'یہ',
#   'کو',
#   'ماٹی',
#   'ناحق',
#   'مست',
#   'ناحق'],
#  ('تم', 'آشنا'): ['تھے'],
#  ('آشنا', 'تھے'): ['تو'],
#  ('تھے', 'تو'): ['تھیں'],
#  ('تو', 'تھیں'): ['آشنائیاں'],
#  ('تھیں', 'آشنائیاں'): ['کیا'],
#  ('آشنائیاں', 'کیا'): ['کیا'],
#  ('\n', 'جدا'): ['تھے'],
#  ('جدا', 'تھے'): ['ہم'],
#  ...}

# %%
print(generate_word_chain(model, 200))
# Out:
# شرح فراق مدح لب مشکبو کریں
#  سینے پہ رکھو تو ہر اک گام زندگی
#  ہم اہل قفس کی صبح چمن میں سرو و سمن سے پہلے
#  غرور حسن سراپا نیاز ہو تیرا
#  حرف سادہ رکھتے ہیں
#  کسی کے دست عنایت نے کنج زنداں میں رفیقوں کے سنہرے چہرے
#  سطح ظلمت سے سیہ مست
#  نئی آنکھوں کے گم گشتہ گہر
#  لوٹا دے
#  ایک امید سے دل ناصبور بے قابو
#  کلام تجھ سے نظر کو بڑے ادب سے ہے
#  ہے دشت اب بھی اعلان سحر کرتا ہوا مست کوئی
#  غزل کی دھن میں غزلخواں ہوئے تو ہیں
#  جیسے چراغ وحشت صرصر سے بے خبر بھی نہیں
#  گر یہ سچ ہے تو جان جاں یہ حرف ترا نام ہی تو ہے
#  اک ماں نے رو کر چوما ہے
#  ہم نے
#  آسماں پر اداس ہیں تارے
#  چاندنی کی تھکی ہوئی آواز
#  ہو نہ ہو
#  سوچنے دو
#  کہ وطن بدر ہوں ہم تم
#  یا خدا یہ مری عمر بڑے بھائی سے کچھ تو ہو
#  جب درد سے رک جائیں گی شمعیں جو ہوا سو ہوا
#  کسی نے گرو رکھ دی
